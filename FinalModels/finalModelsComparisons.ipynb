# %%
import matplotlib.pyplot as plt

plt.plot(["Date Grouping", "Stations Grouping", "Normal Grouping"], [3.6531880855560304, 3.6238197565078734, 3.643830752372742], marker="o")
plt.title("Mean Squared Error - Comparison")
plt.xlabel("Models")
# Out:
# Text(0.5, 0, 'Models')
