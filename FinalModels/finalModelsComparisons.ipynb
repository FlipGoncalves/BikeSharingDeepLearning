# %%
import matplotlib.pyplot as plt

plt.plot(["Date Grouping", "Stations Grouping", "Normal Grouping"], [1, 1, 1], marker="o")
plt.title("Mean Squared Error - Comparison")
plt.xlabel("Models")
# Out:
# Text(0.5, 0, 'Models')
