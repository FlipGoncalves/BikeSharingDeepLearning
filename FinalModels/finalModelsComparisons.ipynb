# %%
import matplotlib.pyplot as plt

# %%
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.1546453573093387, 1.1546453573093387, 1.1546453573093387], marker="o")
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.2, 1.2, 1.2], marker="o")
plt.title("Mean Absolute Error - Regression Comparison")
plt.legend(["Score", "Rounded Score"])
plt.xlabel("Models")
# Out:
# Text(0.5, 0, 'Models')

# %%
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.3683298230171204, 1.4019839406013488, 1.3526817679405212], marker="o")
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.4, 1.4, 1.4], marker="o")
plt.title("Mean Absolute Error - LSTM Comparison")
plt.legend(["Score", "Rounded Score"])
plt.xlabel("Models")
# Out:
# Text(0.5, 0, 'Models')

# %%
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.1546453573093387, 1.1546453573093387, 1.1546453573093387], marker="o")
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.3683298230171204, 1.4019839406013488, 1.3526817679405212], marker="o")
plt.title("Mean Absolute Error - Comparison")
plt.legend(["Regression", "LSTM"])
plt.xlabel("Models")
# Out:
# Text(0.5, 0, 'Models')

# %%
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.2, 1.2, 1.2], marker="o")
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.4, 1.4, 1.4], marker="o")
plt.title("Mean Absolute Error - Comparison")
plt.legend(["Regression", "LSTM"])
plt.xlabel("Models")
# Out:
# Text(0.5, 0, 'Models')

# %%
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.1359407931104395, 1.1378324783630496, 1.1368030068082664], marker="o")
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.3683298230171204, 1.4019839406013488, 1.3526817679405212], marker="o")
plt.title("Mean Absolute Error - Comparison w/ Features")
plt.legend(["Regression", "LSTM"])
plt.xlabel("Models")
# Out:
# Text(0.5, 0, 'Models')

# %%
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.1, 1.1, 1.1], marker="o")
plt.plot(["Date Grouping", "Station Grouping", "Random Grouping"], [1.4, 1.4, 1.4], marker="o")
plt.title("Mean Absolute Error - Comparison")
plt.legend(["Regression", "LSTM"])
plt.xlabel("Models")
# Out:
# Text(0.5, 0, 'Models')
